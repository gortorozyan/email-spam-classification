# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_train = pd.read_csv('train.csv')
df_test = pd.read_csv('test.csv')

# %%
df_train.head()
# Out:
#    id  CustomerId Surname  CreditScore Geography  Gender   Age  Tenure  \
# 0   0  15715707.0   P'eng        685.0    France  Female  31.0     4.0
# 1   1  15651022.0  Ch'ien        590.0    France    Male  43.0     2.0
# 2   2  15589969.0     Yeh        588.0    France    Male  31.0    10.0
# 3   3  15618661.0  Ch'ien        593.0     Spain    Male  37.0     9.0
# 4   4  15771580.0   Nweke        730.0    France  Female  52.0     8.0
#
#     Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0  152582.2            1.0        1.0             1.0        130795.52     0.0
# 1       0.0            2.0        1.0             0.0         96929.24     0.0
# 2       0.0            2.0        1.0             1.0        177896.92     0.0
# 3       0.0            2.0        1.0             0.0         53817.23     0.0
# 4       0.0            1.0        1.0             0.0          1276.87     1.0

# %%
df_test.head()
# Out:
#       id  CustomerId       Surname  CreditScore Geography Gender   Age  \
# 0  15000  15628308.0      Nkemjika        583.0    France   Male  40.0
# 1  15001  15686909.0          Chiu        595.0    France   Male  39.0
# 2  15002  15579616.0      Folliero        622.0    France   Male  24.0
# 3  15003  15795953.0  Chukwubuikem        577.0   Germany   Male  50.0
# 4  15004  15752731.0          Y?an        605.0     Spain   Male  39.0
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0     7.0       0.00            2.0        1.0             0.0
# 1     3.0       0.00            2.0        1.0             0.0
# 2     3.0       0.00            2.0        1.0             0.0
# 3     5.0  127305.50            1.0        1.0             1.0
# 4     2.0   88915.85            1.0        1.0             0.0
#
#    EstimatedSalary
# 0        151481.86
# 1         87400.53
# 2        176712.59
# 3         28806.32
# 4        138521.02

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               15000 non-null  int64
#  1   CustomerId       15000 non-null  float64
#  2   Surname          15000 non-null  object
#  3   CreditScore      15000 non-null  float64
#  4   Geography        15000 non-null  object
#  5   Gender           15000 non-null  object
#  6   Age              15000 non-null  float64
#  7   Tenure           15000 non-null  float64
#  8   Balance          15000 non-null  float64
#  9   NumOfProducts    15000 non-null  float64
#  10  HasCrCard        15000 non-null  float64
#  11  IsActiveMember   15000 non-null  float64
#  12  EstimatedSalary  15000 non-null  float64
#  13  Exited           15000 non-null  float64
# dtypes: float64(10), int64(1), object(3)
# memory usage: 1.6+ MB

# %%
from sklearn.preprocessing import LabelEncoder

# %%
for i in df_train.columns:
    if df_train[i].dtype == object:
        label = LabelEncoder()
        df_train[i] = label.fit_transform(df_train[i])

# %%
for i in df_test.columns:
    if df_test[i].dtype == object:
        label = LabelEncoder()
        df_test[i] = label.fit_transform(df_test[i])

# %%
X = df_train.drop("Exited" ,axis = 1)
y = df_train["Exited"]

# %%
df_train.corr()["Exited"]
# Out:
# id                -0.001285
# CustomerId        -0.004276
# Surname           -0.015834
# CreditScore       -0.032684
# Geography          0.054231
# Gender            -0.183103
# Age                0.466403
# Tenure            -0.028618
# Balance            0.165219
# NumOfProducts     -0.289851
# HasCrCard         -0.024046
# IsActiveMember    -0.215943
# EstimatedSalary    0.023179
# Exited             1.000000
# Name: Exited, dtype: float64

# %%
X = X.drop(["id" , "CustomerId", "Surname", "CreditScore", "Geography", "Tenure" , "HasCrCard" , "EstimatedSalary"] , axis =1 )
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 X = X.drop(["id" , "CustomerId", "Surname", "CreditScore", "Geography", "Tenure" , "HasCrCard" , "EstimatedSalary"] , axis =1 )
#
# File ~\Desktop\ML_18-35\venv\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
# ...

# %%
df_test = df_test.drop(["id" , "CustomerId", "Surname", "CreditScore", "Geography", "Tenure" , "HasCrCard" , "EstimatedSalary"] , axis =1 )

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Gender          10000 non-null  int32
#  1   Age             10000 non-null  float64
#  2   Balance         10000 non-null  float64
#  3   NumOfProducts   10000 non-null  float64
#  4   IsActiveMember  10000 non-null  float64
# dtypes: float64(4), int32(1)
# memory usage: 351.7 KB

# %%
sns.boxplot(X = df_test["Age"])
# Out:
# <Axes: >

# %%
X
# Out:
#        Gender   Age   Balance  NumOfProducts  IsActiveMember
# 0           0  31.0  152582.2            1.0             1.0
# 1           1  43.0       0.0            2.0             0.0
# 2           1  31.0       0.0            2.0             1.0
# 3           1  37.0       0.0            2.0             0.0
# 4           0  52.0       0.0            1.0             0.0
# ...       ...   ...       ...            ...             ...
# 14995       0  29.0       0.0            2.0             0.0
# 14996       1  29.0       0.0            2.0             0.0
# 14997       1  50.0       0.0            2.0             1.0
# 14998       1  37.0       0.0            2.0             1.0
# 14999       1  30.0       0.0            2.0             0.0
#
# [15000 rows x 5 columns]

# %%
len(X["Balance"].unique())
# Out:
# 3351

# %%
sns.boxplot(x=df_train['Age'])
# Out:
# <Axes: xlabel='Age'>

# %%
df_train
# Out:
#           id  CustomerId  Surname  CreditScore  Geography  Gender   Age  \
# 0          0  15715707.0      574        685.0          0       0  31.0
# 1          1  15651022.0       69        590.0          0       1  43.0
# 2          2  15589969.0      727        588.0          0       1  31.0
# 3          3  15618661.0       69        593.0          2       1  37.0
# 4          4  15771580.0      497        730.0          0       0  52.0
# ...      ...         ...      ...          ...        ...     ...   ...
# 14995  14995  15700946.0       92        567.0          0       0  29.0
# 14996  14996  15652084.0      650        476.0          2       1  29.0
# 14997  14997  15657829.0      262        773.0          0       1  50.0
# 14998  14998  15781598.0       67        648.0          0       1  37.0
# 14999  14999  15777772.0      124        635.0          0       1  30.0
#
#        Tenure   Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...
